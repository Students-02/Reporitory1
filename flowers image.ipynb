# %% [markdown]
# <a href="https://colab.research.google.com/github/Students-02/Repository1/blob/main/flowers%20image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Students-02/Repository1
# Out:
# Cloning into 'Repository1'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 23 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (23/23), 3.26 MiB | 20.38 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import cv2

import matplotlib.pyplot as plt

image = cv2.imread('Repository1/flowers.jpg')

# Convert the image from BGR to RGB format

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image

plt.imshow(image_rgb)

plt.title('Original Image')

plt.axis('off')  # Hide the axes

plt.show()
