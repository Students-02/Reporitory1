# %% [markdown]
# <a href="https://colab.research.google.com/github/Students-02/Reporitory1/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

image = Image.open('flowers.jpg')

display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>
